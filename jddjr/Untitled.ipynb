# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_dir = '/Users/zhaohuizhu/datasets/test_data/jddjr/salesForecast/'
df_1 = pd.read_csv(os.path.join(data_dir, 'sale_amt_by_day/shop_1.csv'))
df_2 = pd.read_csv(os.path.join(data_dir, 'sale_amt_by_day/shop_2.csv'))
df_1.shape, df_2.shape
# Out:
# ((271, 2), (271, 2))

# %%
df_1.head()
# Out:
#        ord_dt  sale_amt
# 0  2016-08-03    220.53
# 1  2016-08-04    857.34
# 2  2016-08-05    505.48
# 3  2016-08-06    285.78
# 4  2016-08-07   1052.26

# %%
fig, axes = plt.subplots(ncols=2, figsize=(10, 4))
axes[0].plot(df_1['sale_amt'].tolist())
axes[1].plot(df_2['sale_amt'].tolist())
plt.show()

# %%
(181 - 10 -1)*99
# Out:
# 16830
